# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d 'balraj98/deepglobe-road-extraction-dataset'
# Out:
# Downloading deepglobe-road-extraction-dataset.zip to /content
# 100% 3.79G/3.79G [01:37<00:00, 37.6MB/s]
# 100% 3.79G/3.79G [01:37<00:00, 41.9MB/s]

# %%
shutil.rmtree('road-detection')

# %%
# !unzip deepglobe-road-extraction-dataset.zip -d road-detection
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: road-detection/train/723199_sat.jpg
#   inflating: road-detection/train/723226_mask.png
#   inflating: road-detection/train/723226_sat.jpg
#   inflating: road-detection/train/723436_mask.png
#   inflating: road-detection/train/723436_sat.jpg
#   inflating: road-detection/train/723483_mask.png
#   inflating: road-detection/train/723483_sat.jpg
#   inflating: road-detection/train/723622_mask.png
#   inflating: road-detection/train/723622_sat.jpg
#   inflating: road-detection/train/723722_mask.png
#   inflating: road-detection/train/723722_sat.jpg
#   inflating: road-detection/train/723970_mask.png
#   inflating: road-detection/train/723970_sat.jpg
#   inflating: road-detection/train/723990_mask.png
#   inflating: road-detection/train/723990_sat.jpg
#   inflating: road-detection/train/724095_mask.png
#   inflating: road-detection/train/724095_sat.jpg
#   inflating: road-detection/train/724431_mask.png
#   inflating: road-detection/train/724431_sat.jpg
#   inflating: road-detection/train/724485_mask.png
#   inflating: road-detection/train/724485_sat.jpg
#   inflating: road-detection/train/724705_mask.png
#   inflating: road-detection/train/724705_sat.jpg
#   inflating: road-detection/train/724870_mask.png
#   inflating: road-detection/train/724870_sat.jpg
#   inflating: road-detection/train/724941_mask.png
#   inflating: road-detection/train/724941_sat.jpg
#   inflating: road-detection/train/724993_mask.png
#   inflating: road-detection/train/724993_sat.jpg
#   inflating: road-detection/train/725014_mask.png
#   inflating: road-detection/train/725014_sat.jpg
#   inflating: road-detection/train/725115_mask.png
#   inflating: road-detection/train/725115_sat.jpg
#   inflating: road-detection/train/725183_mask.png
#   inflating: road-detection/train/725183_sat.jpg
#   inflating: road-detection/train/725239_mask.png
#   inflating: road-detection/train/725239_sat.jpg
#   inflating: road-detection/train/725249_mask.png
#   inflating: road-detection/train/725249_sat.jpg
#   inflating: road-detection/train/725359_mask.png
#   inflating: road-detection/train/725359_sat.jpg
#   inflating: road-detection/train/725392_mask.png
#   inflating: road-detection/train/725392_sat.jpg
#   inflating: road-detection/train/725472_mask.png
#   inflating: road-detection/train/725472_sat.jpg
#   inflating: road-detection/train/725747_mask.png
#   inflating: road-detection/train/725747_sat.jpg
#   inflating: road-detection/train/725833_mask.png
#   inflating: road-detection/train/725833_sat.jpg
#   inflating: road-detection/train/725843_mask.png
#   inflating: road-detection/train/725843_sat.jpg
#   inflating: road-detection/train/726148_mask.png
#   inflating: road-detection/train/726148_sat.jpg
#   inflating: road-detection/train/726271_mask.png
#   inflating: road-detection/train/726271_sat.jpg
#   inflating: road-detection/train/726557_mask.png
#   inflating: road-detection/train/726557_sat.jpg
#   inflating: road-detection/train/726668_mask.png
#   inflating: road-detection/train/726668_sat.jpg
#   inflating: road-detection/train/72689_mask.png
#   inflating: road-detection/train/72689_sat.jpg
#   inflating: road-detection/train/727230_mask.png
#   inflating: road-detection/train/727230_sat.jpg
#   inflating: road-detection/train/727315_mask.png
#   inflating: road-detection/train/727315_sat.jpg
#   inflating: road-detection/train/727435_mask.png
#   inflating: road-detection/train/727435_sat.jpg
#   inflating: road-detection/train/727513_mask.png
#   inflating: road-detection/train/727513_sat.jpg
#   inflating: road-detection/train/727773_mask.png
#   inflating: road-detection/train/727773_sat.jpg
#   inflating: road-detection/train/727840_mask.png
#   inflating: road-detection/train/727840_sat.jpg
#   inflating: road-detection/train/728547_mask.png
#   inflating: road-detection/train/728547_sat.jpg
#   inflating: road-detection/train/728843_mask.png
#   inflating: road-detection/train/728843_sat.jpg
#   inflating: road-detection/train/729020_mask.png
#   inflating: road-detection/train/729020_sat.jpg
#   inflating: road-detection/train/729246_mask.png
#   inflating: road-detection/train/729246_sat.jpg
#   inflating: road-detection/train/729444_mask.png
#   inflating: road-detection/train/729444_sat.jpg
#   inflating: road-detection/train/729661_mask.png
#   inflating: road-detection/train/729661_sat.jpg
#   inflating: road-detection/train/729885_mask.png
#   inflating: road-detection/train/729885_sat.jpg
#   inflating: road-detection/train/730185_mask.png
#   inflating: road-detection/train/730185_sat.jpg
#   inflating: road-detection/train/730270_mask.png
#   inflating: road-detection/train/730270_sat.jpg
#   inflating: road-detection/train/730281_mask.png
#   inflating: road-detection/train/730281_sat.jpg
#   inflating: road-detection/train/73033_mask.png
#   inflating: road-detection/train/73033_sat.jpg
#   inflating: road-detection/train/730376_mask.png
#   inflating: road-detection/train/730376_sat.jpg
#   inflating: road-detection/train/730524_mask.png
#   inflating: road-detection/train/730524_sat.jpg
#   inflating: road-detection/train/730531_mask.png
#   inflating: road-detection/train/730531_sat.jpg
#   inflating: road-detection/train/730614_mask.png
#   inflating: road-detection/train/730614_sat.jpg
#   inflating: road-detection/train/730763_mask.png
#   inflating: road-detection/train/730763_sat.jpg
#   inflating: road-detection/train/730949_mask.png
#   inflating: road-detection/train/730949_sat.jpg
#   inflating: road-detection/train/730973_mask.png
#   inflating: road-detection/train/730973_sat.jpg
#   inflating: road-detection/train/731150_mask.png
#   inflating: road-detection/train/731150_sat.jpg
#   inflating: road-detection/train/731187_mask.png
#   inflating: road-detection/train/731187_sat.jpg
#   inflating: road-detection/train/731391_mask.png
#   inflating: road-detection/train/731391_sat.jpg
#   inflating: road-detection/train/731685_mask.png
#   inflating: road-detection/train/731685_sat.jpg
#   inflating: road-detection/train/73183_mask.png
#   inflating: road-detection/train/73183_sat.jpg
#   inflating: road-detection/train/731856_mask.png
#   inflating: road-detection/train/731856_sat.jpg
#   inflating: road-detection/train/73185_mask.png
#   inflating: road-detection/train/73185_sat.jpg
#   inflating: road-detection/train/732011_mask.png
#   inflating: road-detection/train/732011_sat.jpg
#   inflating: road-detection/train/732079_mask.png
#   inflating: road-detection/train/732079_sat.jpg
#   inflating: road-detection/train/732273_mask.png
#   inflating: road-detection/train/732273_sat.jpg
#   inflating: road-detection/train/732310_mask.png
#   inflating: road-detection/train/732310_sat.jpg
#   inflating: road-detection/train/732602_mask.png
#   inflating: road-detection/train/7372_sat.jpg
#   inflating: road-detection/train/737508_mask.png
#   inflating: road-detection/train/737508_sat.jpg
#   inflating: road-detection/train/737584_mask.png
#   inflating: road-detection/train/737584_sat.jpg
#   inflating: road-detection/train/737666_mask.png
#   inflating: road-detection/train/737666_sat.jpg
#   inflating: road-detection/train/738170_mask.png
#   inflating: road-detection/train/738170_sat.jpg
#   inflating: road-detection/train/738407_mask.png
#   inflating: road-detection/train/738407_sat.jpg
#   inflating: road-detection/train/738456_mask.png
#   inflating: road-detection/train/738456_sat.jpg
#   inflating: road-detection/train/73857_mask.png
#   inflating: road-detection/train/73857_sat.jpg
#   inflating: road-detection/train/73867_mask.png
#   inflating: road-detection/train/73867_sat.jpg
#   inflating: road-detection/train/738721_mask.png
#   inflating: road-detection/train/738721_sat.jpg
#   inflating: road-detection/train/738813_mask.png
#   inflating: road-detection/train/738813_sat.jpg
#   inflating: road-detection/train/738906_mask.png
#   inflating: road-detection/train/738906_sat.jpg
#   inflating: road-detection/train/739225_mask.png
#   inflating: road-detection/train/739225_sat.jpg
#   inflating: road-detection/train/739465_mask.png
#   inflating: road-detection/train/739465_sat.jpg
#   inflating: road-detection/train/73959_mask.png
#   inflating: road-detection/train/73959_sat.jpg
#   inflating: road-detection/train/739815_mask.png
#   inflating: road-detection/train/739815_sat.jpg
#   inflating: road-detection/train/74010_mask.png
#   inflating: road-detection/train/74010_sat.jpg
#   inflating: road-detection/train/740261_mask.png
#   inflating: road-detection/train/740261_sat.jpg
#   inflating: road-detection/train/74057_mask.png
#   inflating: road-detection/train/74057_sat.jpg
#   inflating: road-detection/train/740865_mask.png
#   inflating: road-detection/train/740865_sat.jpg
#   inflating: road-detection/train/741188_mask.png
#   inflating: road-detection/train/741188_sat.jpg
#   inflating: road-detection/train/74143_mask.png
#   inflating: road-detection/train/74143_sat.jpg
#   inflating: road-detection/train/741476_mask.png
#   inflating: road-detection/train/741476_sat.jpg
#   inflating: road-detection/train/741508_mask.png
#   inflating: road-detection/train/741508_sat.jpg
#   inflating: road-detection/train/741728_mask.png
#   inflating: road-detection/train/741728_sat.jpg
#   inflating: road-detection/train/741749_mask.png
#   inflating: road-detection/train/741749_sat.jpg
#   inflating: road-detection/train/742031_mask.png
#   inflating: road-detection/train/742031_sat.jpg
#   inflating: road-detection/train/742141_mask.png
#   inflating: road-detection/train/742141_sat.jpg
#   inflating: road-detection/train/742390_mask.png
#   inflating: road-detection/train/742390_sat.jpg
#   inflating: road-detection/train/742461_mask.png
#   inflating: road-detection/train/742461_sat.jpg
#   inflating: road-detection/train/742678_mask.png
#   inflating: road-detection/train/742678_sat.jpg
#   inflating: road-detection/train/742880_mask.png
#   inflating: road-detection/train/742880_sat.jpg
#   inflating: road-detection/train/743007_mask.png
#   inflating: road-detection/train/743007_sat.jpg
#   inflating: road-detection/train/743078_mask.png
#   inflating: road-detection/train/743078_sat.jpg
#   inflating: road-detection/train/743232_mask.png
#   inflating: road-detection/train/743232_sat.jpg
#   inflating: road-detection/train/743450_mask.png
#   inflating: road-detection/train/743450_sat.jpg
#   inflating: road-detection/train/743506_mask.png
#   inflating: road-detection/train/743506_sat.jpg
#   inflating: road-detection/train/743617_mask.png
#   inflating: road-detection/train/743617_sat.jpg
#   inflating: road-detection/train/743645_mask.png
#   inflating: road-detection/train/743645_sat.jpg
#   inflating: road-detection/train/744056_mask.png
#   inflating: road-detection/train/744056_sat.jpg
#   inflating: road-detection/train/744091_mask.png
#   inflating: road-detection/train/744091_sat.jpg
#   inflating: road-detection/train/744092_mask.png
#   inflating: road-detection/train/744092_sat.jpg
#   inflating: road-detection/train/744129_mask.png
#   inflating: road-detection/train/744129_sat.jpg
#   inflating: road-detection/train/744188_mask.png
#   inflating: road-detection/train/744188_sat.jpg
#   inflating: road-detection/train/744794_mask.png
#   inflating: road-detection/train/744794_sat.jpg
#   inflating: road-detection/train/744973_mask.png
#   inflating: road-detection/train/744973_sat.jpg
#   inflating: road-detection/train/744975_mask.png
#   inflating: road-detection/train/744975_sat.jpg
#   inflating: road-detection/train/74497_mask.png
#   inflating: road-detection/train/74497_sat.jpg
#   inflating: road-detection/train/745086_mask.png
#   inflating: road-detection/train/745086_sat.jpg
#   inflating: road-detection/train/745107_mask.png
#   inflating: road-detection/train/745107_sat.jpg
#   inflating: road-detection/train/745266_mask.png
#   inflating: road-detection/train/745266_sat.jpg
#   inflating: road-detection/train/74552_mask.png
#   inflating: road-detection/train/74552_sat.jpg
#   inflating: road-detection/train/745704_mask.png
#   inflating: road-detection/train/745704_sat.jpg
#   inflating: road-detection/train/745880_mask.png
#   inflating: road-detection/train/745880_sat.jpg
#   inflating: road-detection/train/745902_mask.png
#   inflating: road-detection/train/745902_sat.jpg
#   inflating: road-detection/train/746005_mask.png
#   inflating: road-detection/train/746005_sat.jpg
#   inflating: road-detection/train/74600_mask.png
#   inflating: road-detection/train/74600_sat.jpg
#   inflating: road-detection/train/746094_mask.png
#   inflating: road-detection/train/746094_sat.jpg
#   inflating: road-detection/train/746431_mask.png
#   inflating: road-detection/train/746431_sat.jpg
#   inflating: road-detection/train/746499_mask.png
#   inflating: road-detection/train/746499_sat.jpg
#   inflating: road-detection/train/746743_mask.png
#   inflating: road-detection/train/746743_sat.jpg
#   inflating: road-detection/train/746839_mask.png
#   inflating: road-detection/train/746839_sat.jpg
#   inflating: road-detection/train/747312_mask.png
#   inflating: road-detection/train/747312_sat.jpg
#   inflating: road-detection/train/74737_mask.png
#   inflating: road-detection/train/74737_sat.jpg
#   inflating: road-detection/train/747392_mask.png
#   inflating: road-detection/train/747392_sat.jpg
#   inflating: road-detection/train/747616_mask.png
#   inflating: road-detection/train/747616_sat.jpg
#   inflating: road-detection/train/748045_mask.png
#   inflating: road-detection/train/748045_sat.jpg
#   inflating: road-detection/train/748093_mask.png
#   inflating: road-detection/train/748093_sat.jpg
#   inflating: road-detection/train/748425_mask.png
#   inflating: road-detection/train/748425_sat.jpg
#   inflating: road-detection/train/748548_mask.png
#   inflating: road-detection/train/748548_sat.jpg
#   inflating: road-detection/train/748601_mask.png
#   inflating: road-detection/train/748601_sat.jpg
#   inflating: road-detection/train/748913_mask.png
#   inflating: road-detection/train/748913_sat.jpg
#   inflating: road-detection/train/748989_mask.png
#   inflating: road-detection/train/748989_sat.jpg
#   inflating: road-detection/train/749627_mask.png
#   inflating: road-detection/train/749627_sat.jpg
#   inflating: road-detection/train/749641_mask.png
#   inflating: road-detection/train/749641_sat.jpg
#   inflating: road-detection/train/749648_mask.png
#   inflating: road-detection/train/749648_sat.jpg
#   inflating: road-detection/train/749787_mask.png
#   inflating: road-detection/train/749787_sat.jpg
#   inflating: road-detection/train/749859_mask.png
#   inflating: road-detection/train/749859_sat.jpg
#   inflating: road-detection/train/74988_mask.png
#   inflating: road-detection/train/74988_sat.jpg
#   inflating: road-detection/train/74989_mask.png
#   inflating: road-detection/train/74989_sat.jpg
#   inflating: road-detection/train/750187_mask.png
#   inflating: road-detection/train/750187_sat.jpg
#   inflating: road-detection/train/750210_mask.png
#   inflating: road-detection/train/750210_sat.jpg
#   inflating: road-detection/train/750445_mask.png
#   inflating: road-detection/train/750445_sat.jpg
#   inflating: road-detection/train/750485_mask.png
#   inflating: road-detection/train/750485_sat.jpg
#   inflating: road-detection/train/750530_mask.png
#   inflating: road-detection/train/750530_sat.jpg
#   inflating: road-detection/train/750608_mask.png
#   inflating: road-detection/train/750608_sat.jpg
#   inflating: road-detection/train/750772_mask.png
#   inflating: road-detection/train/750772_sat.jpg
#   inflating: road-detection/train/750897_mask.png
#   inflating: road-detection/train/750897_sat.jpg
#   inflating: road-detection/train/750956_mask.png
#   inflating: road-detection/train/750956_sat.jpg
#   inflating: road-detection/train/751202_mask.png
#   inflating: road-detection/train/751202_sat.jpg
#   inflating: road-detection/train/751448_mask.png
#   inflating: road-detection/train/751448_sat.jpg
#   inflating: road-detection/train/751585_mask.png
#   inflating: road-detection/train/751585_sat.jpg
#   inflating: road-detection/train/751700_mask.png
#   inflating: road-detection/train/751700_sat.jpg
#   inflating: road-detection/train/752005_mask.png
#   inflating: road-detection/train/752005_sat.jpg
#   inflating: road-detection/train/752517_mask.png
#   inflating: road-detection/train/752517_sat.jpg
#   inflating: road-detection/train/752601_mask.png
#   inflating: road-detection/train/752601_sat.jpg
#   inflating: road-detection/train/752614_mask.png
#   inflating: road-detection/train/752614_sat.jpg
#   inflating: road-detection/train/752708_mask.png
#   inflating: road-detection/train/752708_sat.jpg
#   inflating: road-detection/train/753016_mask.png
#   inflating: road-detection/train/753016_sat.jpg
#   inflating: road-detection/train/753215_mask.png
#   inflating: road-detection/train/753215_sat.jpg
#   inflating: road-detection/train/75330_mask.png
#   inflating: road-detection/train/75330_sat.jpg
#   inflating: road-detection/train/753384_mask.png
#   inflating: road-detection/train/753384_sat.jpg
#   inflating: road-detection/train/753390_mask.png
#   inflating: road-detection/train/753390_sat.jpg
#   inflating: road-detection/train/753614_mask.png
#   inflating: road-detection/train/753614_sat.jpg
#   inflating: road-detection/train/753638_mask.png
#   inflating: road-detection/train/753638_sat.jpg
#   inflating: road-detection/train/753663_mask.png
#   inflating: road-detection/train/753663_sat.jpg
#   inflating: road-detection/train/753676_mask.png
#   inflating: road-detection/train/753676_sat.jpg
#   inflating: road-detection/train/753694_mask.png
#   inflating: road-detection/train/753694_sat.jpg
#   inflating: road-detection/train/753907_mask.png
#   inflating: road-detection/train/753907_sat.jpg
#   inflating: road-detection/train/754467_mask.png
#   inflating: road-detection/train/754467_sat.jpg
#   inflating: road-detection/train/754506_mask.png
#   inflating: road-detection/train/754506_sat.jpg
#   inflating: road-detection/train/754539_mask.png
#   inflating: road-detection/train/754539_sat.jpg
#   inflating: road-detection/train/754670_mask.png
#   inflating: road-detection/train/754670_sat.jpg
#   inflating: road-detection/train/754944_mask.png
#   inflating: road-detection/train/754944_sat.jpg
#   inflating: road-detection/train/754948_mask.png
#   inflating: road-detection/train/754948_sat.jpg
#   inflating: road-detection/train/755069_mask.png
#   inflating: road-detection/train/755069_sat.jpg
#   inflating: road-detection/train/755342_mask.png
#   inflating: road-detection/train/755342_sat.jpg
#   inflating: road-detection/train/755362_mask.png
#   inflating: road-detection/train/755362_sat.jpg
#   inflating: road-detection/train/755575_mask.png
#   inflating: road-detection/train/755575_sat.jpg
#   inflating: road-detection/train/755605_mask.png
#   inflating: road-detection/train/755605_sat.jpg
#   inflating: road-detection/train/75561_mask.png
#   inflating: road-detection/train/75561_sat.jpg
#   inflating: road-detection/train/755736_mask.png
#   inflating: road-detection/train/755736_sat.jpg
#   inflating: road-detection/train/755954_mask.png
#   inflating: road-detection/train/755954_sat.jpg
#   inflating: road-detection/train/755970_mask.png
#   inflating: road-detection/train/755970_sat.jpg
#   inflating: road-detection/train/756116_mask.png
#   inflating: road-detection/train/756116_sat.jpg
#   inflating: road-detection/train/75611_mask.png
#   inflating: road-detection/train/75611_sat.jpg
#   inflating: road-detection/train/756844_mask.png
#   inflating: road-detection/train/756844_sat.jpg
#   inflating: road-detection/train/757028_mask.png
#   inflating: road-detection/train/757028_sat.jpg
#   inflating: road-detection/train/757146_mask.png
#   inflating: road-detection/train/757146_sat.jpg
#   inflating: road-detection/train/757279_mask.png
#   inflating: road-detection/train/757279_sat.jpg
#   inflating: road-detection/train/757333_mask.png
#   inflating: road-detection/train/757333_sat.jpg
#   inflating: road-detection/train/757498_mask.png
#   inflating: road-detection/train/757498_sat.jpg
#   inflating: road-detection/train/757554_mask.png
#   inflating: road-detection/train/757554_sat.jpg
#   inflating: road-detection/train/757803_mask.png
#   inflating: road-detection/train/757803_sat.jpg
#   inflating: road-detection/train/757829_mask.png
#   inflating: road-detection/train/757829_sat.jpg
#   inflating: road-detection/train/757855_mask.png
#   inflating: road-detection/train/757855_sat.jpg
#   inflating: road-detection/train/757922_mask.png
#   inflating: road-detection/train/757922_sat.jpg
#   inflating: road-detection/train/75815_mask.png
#   inflating: road-detection/train/75815_sat.jpg
#   inflating: road-detection/train/758229_mask.png
#   inflating: road-detection/train/758229_sat.jpg
#   inflating: road-detection/train/758267_mask.png
#   inflating: road-detection/train/758267_sat.jpg
#   inflating: road-detection/train/758397_mask.png
#   inflating: road-detection/train/758397_sat.jpg
#   inflating: road-detection/train/758481_mask.png
#   inflating: road-detection/train/758481_sat.jpg
#   inflating: road-detection/train/758578_mask.png
#   inflating: road-detection/train/758578_sat.jpg
#   inflating: road-detection/train/758682_mask.png
#   inflating: road-detection/train/758682_sat.jpg
#   inflating: road-detection/train/758734_mask.png
#   inflating: road-detection/train/758734_sat.jpg
#   inflating: road-detection/train/758779_mask.png
#   inflating: road-detection/train/758779_sat.jpg
#   inflating: road-detection/train/758828_mask.png
#   inflating: road-detection/train/758828_sat.jpg
#   inflating: road-detection/train/758957_mask.png
#   inflating: road-detection/train/758957_sat.jpg
#   inflating: road-detection/train/758973_mask.png
#   inflating: road-detection/train/758973_sat.jpg
#   inflating: road-detection/train/759019_mask.png
#   inflating: road-detection/train/759019_sat.jpg
#   inflating: road-detection/train/759091_mask.png
#   inflating: road-detection/train/759091_sat.jpg
#   inflating: road-detection/train/759166_mask.png
#   inflating: road-detection/train/759166_sat.jpg
#   inflating: road-detection/train/759355_mask.png
#   inflating: road-detection/train/759355_sat.jpg
#   inflating: road-detection/train/759445_mask.png
#   inflating: road-detection/train/759445_sat.jpg
#   inflating: road-detection/train/759537_mask.png
#   inflating: road-detection/train/759537_sat.jpg
#   inflating: road-detection/train/759607_mask.png
#   inflating: road-detection/train/759607_sat.jpg
#   inflating: road-detection/train/759655_mask.png
#   inflating: road-detection/train/759655_sat.jpg
#   inflating: road-detection/train/759945_mask.png
#   inflating: road-detection/train/759945_sat.jpg
#   inflating: road-detection/train/759949_mask.png
#   inflating: road-detection/train/759949_sat.jpg
#   inflating: road-detection/train/760036_mask.png
#   inflating: road-detection/train/760036_sat.jpg
#   inflating: road-detection/train/760069_mask.png
#   inflating: road-detection/train/760069_sat.jpg
#   inflating: road-detection/train/760170_mask.png
#   inflating: road-detection/train/760170_sat.jpg
#   inflating: road-detection/train/760255_mask.png
#   inflating: road-detection/train/760255_sat.jpg
#   inflating: road-detection/train/760294_mask.png
#   inflating: road-detection/train/760294_sat.jpg
#   inflating: road-detection/train/760338_mask.png
#   inflating: road-detection/train/760338_sat.jpg
#   inflating: road-detection/train/760377_mask.png
#   inflating: road-detection/train/760377_sat.jpg
#   inflating: road-detection/train/760436_mask.png
#   inflating: road-detection/train/760436_sat.jpg
#   inflating: road-detection/train/760891_mask.png
#   inflating: road-detection/train/760891_sat.jpg
#   inflating: road-detection/train/760962_mask.png
#   inflating: road-detection/train/760962_sat.jpg
#   inflating: road-detection/train/761056_mask.png
#   inflating: road-detection/train/761056_sat.jpg
#   inflating: road-detection/train/761119_mask.png
#   inflating: road-detection/train/761119_sat.jpg
#   inflating: road-detection/train/761239_mask.png
#   inflating: road-detection/train/761239_sat.jpg
#   inflating: road-detection/train/761646_mask.png
#   inflating: road-detection/train/761646_sat.jpg
#   inflating: road-detection/train/761666_mask.png
#   inflating: road-detection/train/761666_sat.jpg
#   inflating: road-detection/train/761866_mask.png
#   inflating: road-detection/train/761866_sat.jpg
#   inflating: road-detection/train/762023_mask.png
#   inflating: road-detection/train/762023_sat.jpg
#   inflating: road-detection/train/762116_mask.png
#   inflating: road-detection/train/767726_sat.jpg
#   inflating: road-detection/train/767812_mask.png
#   inflating: road-detection/train/767812_sat.jpg
#   inflating: road-detection/train/767819_mask.png
#   inflating: road-detection/train/767819_sat.jpg
#   inflating: road-detection/train/768007_mask.png
#   inflating: road-detection/train/768007_sat.jpg
#   inflating: road-detection/train/768045_mask.png
#   inflating: road-detection/train/768045_sat.jpg
#   inflating: road-detection/train/768086_mask.png
#   inflating: road-detection/train/768086_sat.jpg
#   inflating: road-detection/train/768224_mask.png
#   inflating: road-detection/train/768224_sat.jpg
#   inflating: road-detection/train/768401_mask.png
#   inflating: road-detection/train/768401_sat.jpg
#   inflating: road-detection/train/768818_mask.png
#   inflating: road-detection/train/768818_sat.jpg
#   inflating: road-detection/train/769104_mask.png
#   inflating: road-detection/train/769104_sat.jpg
#   inflating: road-detection/train/769154_mask.png
#   inflating: road-detection/train/769154_sat.jpg
#   inflating: road-detection/train/769287_mask.png
#   inflating: road-detection/train/769287_sat.jpg
#   inflating: road-detection/train/769360_mask.png
#   inflating: road-detection/train/769360_sat.jpg
#   inflating: road-detection/train/769376_mask.png
#   inflating: road-detection/train/769376_sat.jpg
#   inflating: road-detection/train/769666_mask.png
#   inflating: road-detection/train/769666_sat.jpg
#   inflating: road-detection/train/769777_mask.png
#   inflating: road-detection/train/769777_sat.jpg
#   inflating: road-detection/train/769782_mask.png
#   inflating: road-detection/train/769782_sat.jpg
#   inflating: road-detection/train/769940_mask.png
#   inflating: road-detection/train/769940_sat.jpg
#   inflating: road-detection/train/769960_mask.png
#   inflating: road-detection/train/769960_sat.jpg
#   inflating: road-detection/train/770001_mask.png
#   inflating: road-detection/train/770001_sat.jpg
#   inflating: road-detection/train/770292_mask.png
#   inflating: road-detection/train/770292_sat.jpg
#   inflating: road-detection/train/770434_mask.png
#   inflating: road-detection/train/770434_sat.jpg
#   inflating: road-detection/train/770503_mask.png
#   inflating: road-detection/train/770503_sat.jpg
#   inflating: road-detection/train/770634_mask.png
#   inflating: road-detection/train/770634_sat.jpg
#   inflating: road-detection/train/770659_mask.png
#   inflating: road-detection/train/770659_sat.jpg
#   inflating: road-detection/train/770696_mask.png
#   inflating: road-detection/train/770696_sat.jpg
#   inflating: road-detection/train/77085_mask.png
#   inflating: road-detection/train/77085_sat.jpg
#   inflating: road-detection/train/770882_mask.png
#   inflating: road-detection/train/770882_sat.jpg
#   inflating: road-detection/train/771036_mask.png
#   inflating: road-detection/train/771036_sat.jpg
#   inflating: road-detection/train/771180_mask.png
#   inflating: road-detection/train/771180_sat.jpg
#   inflating: road-detection/train/771314_mask.png
#   inflating: road-detection/train/771314_sat.jpg
#   inflating: road-detection/train/771348_mask.png
#   inflating: road-detection/train/771348_sat.jpg
#   inflating: road-detection/train/771440_mask.png
#   inflating: road-detection/train/771440_sat.jpg
#   inflating: road-detection/train/771451_mask.png
#   inflating: road-detection/train/771451_sat.jpg
#   inflating: road-detection/train/771504_mask.png
#   inflating: road-detection/train/771504_sat.jpg
#   inflating: road-detection/train/771517_mask.png
#   inflating: road-detection/valid/991978_sat.jpg
#   inflating: road-detection/valid/992520_sat.jpg
#   inflating: road-detection/valid/993282_sat.jpg
#   inflating: road-detection/valid/993402_sat.jpg
#   inflating: road-detection/valid/993408_sat.jpg
#   inflating: road-detection/valid/993415_sat.jpg
#   inflating: road-detection/valid/994006_sat.jpg
#   inflating: road-detection/valid/994111_sat.jpg
#   inflating: road-detection/valid/994141_sat.jpg
#   inflating: road-detection/valid/994375_sat.jpg
#   inflating: road-detection/valid/994998_sat.jpg
#   inflating: road-detection/valid/995317_sat.jpg
#   inflating: road-detection/valid/995370_sat.jpg
#   inflating: road-detection/valid/995930_sat.jpg
#   inflating: road-detection/valid/997473_sat.jpg
#   inflating: road-detection/valid/998148_sat.jpg
#   inflating: road-detection/valid/999753_sat.jpg

# %%
import os
import shutil


input_dir = 'road-detection/train'


output_sat_dir = os.path.join(input_dir, 'sat')
output_mask_dir = os.path.join(input_dir, 'mask')

os.makedirs(output_sat_dir, exist_ok=True)
os.makedirs(output_mask_dir, exist_ok=True)


for filename in os.listdir(input_dir):
    if filename.endswith('sat.jpg'):
        shutil.move(os.path.join(input_dir, filename), os.path.join(output_sat_dir, filename))
    elif filename.endswith('mask.png'):
        shutil.move(os.path.join(input_dir, filename), os.path.join(output_mask_dir, filename))

# %%
import splitfolders
splitfolders.ratio('road-detection/train', output="datasplit", seed=1337, ratio=(.8, 0.1,0.1))
# Out:
# Copying files: 12452 files [00:36, 344.84 files/s]

# %%
def test():
  train_set = SatDataset(
        image_dir='datasplit/train/sat',
        mask_dir='datasplit/train/mask',
    )

  train_loader = torch.utils.data.DataLoader(
        train_set,
        batch_size=16
    )

  next(iter(train_loader))

test()

# %%
len(os.listdir('road-detection/train_dup/sat'))
# Out:
# 4975

# %%
os.path.isfile('road-detection/val_split/mask/135671_mask.png')
# Out:
# True

# %%
import os
from PIL import Image
from torch.utils.data import Dataset
import numpy as np

class SatDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        img_path = os.path.join(self.image_dir, self.images[index])
        mask_path = os.path.join(self.mask_dir, self.images[index].replace("sat.jpg", "mask.png"))
        image = np.array(Image.open(img_path).convert("RGB"))
        mask = np.array(Image.open(mask_path).convert("L"), dtype=np.float32)
        mask[mask == 255.0] = 1.0

        if self.transform is not None:
            augmentations = self.transform(image=image, mask=mask)
            image = augmentations["image"]
            mask = augmentations["mask"]

        return image, mask

# %%
def get_loaders(
    train_dir,
    train_maskdir,
    val_dir,
    val_maskdir,
    batch_size,
    train_transform,
    val_transform,
    num_workers=4,
    pin_memory=True,
):
    train_set = SatDataset(
        image_dir=train_dir,
        mask_dir=train_maskdir,
        transform=train_transform,

    )

    train_loader = torch.utils.data.DataLoader(
        train_set,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=pin_memory,
        shuffle=True,
    )

    val_set = SatDataset(
        image_dir = val_dir,
        mask_dir= val_maskdir,
        transform= val_transform
    )

    val_loader = torch.utils.data.DataLoader(
        val_set,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=pin_memory,
        shuffle=False,
    )

    return train_loader, val_loader

# %%
from torchvision.transforms import v2
import torch

import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose(
        [
            A.Resize(height=256, width=256),
            A.Rotate(limit=35, p=1.0),
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.1),
            A.Normalize(
                mean=[0.0, 0.0, 0.0],
                std=[1.0, 1.0, 1.0],
                max_pixel_value=255.0,
            ),
            ToTensorV2(),
        ],
    )

val_transforms = A.Compose(
        [
            A.Resize(height=256, width=256),
            A.Normalize(
                mean=[0.0, 0.0, 0.0],
                std=[1.0, 1.0, 1.0],
                max_pixel_value=255.0,
            ),
            ToTensorV2(),
        ],
    )

TRAIN_IMG_DIR = "datasplit/train/sat/"
TRAIN_MASK_DIR = "datasplit/train/mask/"

VAL_IMG_DIR = "datasplit/test/sat/"
VAL_MASK_DIR = "datasplit/test/mask/"

BATCH_SIZE= 16
PIN_MEMORY = True
NUM_WORKERS = 2

train_loader, val_loader = get_loaders(
        TRAIN_IMG_DIR,
        TRAIN_MASK_DIR,
        VAL_IMG_DIR,
        VAL_MASK_DIR,
        BATCH_SIZE,
        train_transform,
        val_transforms,
        NUM_WORKERS,
        PIN_MEMORY,
    )

# %%
os.path.isfile('road-detection/val_dup/mask/760255_mask.png')
# Out:
# True

# %%
mask_imgs[0].shape
# Out:
# torch.Size([256, 256])

# %%
sat_imgs[0].shape
# Out:
# torch.Size([1024, 1024, 3])

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1,2, figsize=(10,10))
sat_img = sat_imgs[0].cpu()
mask_img = mask_imgs[0].cpu()

ax[0].imshow(sat_img)
ax[1].imshow(mask_img, cmap='gray')

# %%
import torch.nn as nn


class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),

            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )
    def forward(self, X):
        return self.conv(X)

# %%
class UNET(nn.Module):
    def __init__(self, in_channels=3, out_channels=1, features=[64, 128, 256, 512]):
        super(UNET, self).__init__()
        self.ups = nn.ModuleList()
        self.downs =nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        for feature in reversed(features):
            self.ups.append(nn.ConvTranspose2d(in_channels=feature*2, out_channels= feature, kernel_size=2, stride=2)) # multiply feature by 2 to account for skip connection
            self.ups.append(DoubleConv(feature*2, feature))

        self.bottleneck = DoubleConv(in_channels=features[-1], out_channels=features[-1]*2)
        self.final=  nn.Conv2d(features[0], out_channels=out_channels, kernel_size=1)

    def forward(self, X):
        skip_connections = []
        for i, down in enumerate(self.downs):
            X = down(X)
            skip_connections.append(X)
            X = self.pool(X)


        X = self.bottleneck(X)
        skip_connections = list(reversed(skip_connections))


        for i in range(0, len(self.ups), 2):
            X = self.ups[i](X)
            skip_conn = skip_connections[i//2]
            #if X.shape != skip_conn.shape:
                #X = TF.resize(X, size=skip_conn.shape[2:])

            concat_skip = torch.cat((skip_conn,X), dim=1)
            X = self.ups[i+1](concat_skip)

        finalX = self.final(X)
        return self.final(X)

# %%
def check_accuracy(loader, model, device="cuda"):
    num_correct = 0
    num_pixels = 0
    dice_score = 0
    model.eval()

    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            y = y.to(device).unsqueeze(1)
            preds = torch.sigmoid(model(x))
            preds = (preds > 0.5).float()
            num_correct += (preds == y).sum()
            num_pixels += torch.numel(preds)
            dice_score += (2 * (preds * y).sum()) / (
                (preds + y).sum() + 1e-8
            )

    print(
        f"Got {num_correct}/{num_pixels} with acc {num_correct/num_pixels*100:.2f}"
    )
    print(f"Dice score: {dice_score/len(loader)}")
    model.train()

# %%
def train_fn(loader, model, optimizer, loss_fn, scaler):
    loop = tqdm(loader)

    for batch_idx, (data, targets) in enumerate(loop):
        data = data.to(device='cuda')
        targets = targets.float().unsqueeze(1).to(device='cuda')


        with torch.cuda.amp.autocast():
            predictions = model(data)
            loss = loss_fn(predictions, targets)

        # backward
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # update tqdm loop
        loop.set_postfix(loss=loss.item())

# %%
import torchvision

def save_checkpoint(state, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)

def load_checkpoint(checkpoint, model):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])

def save_predictions_as_imgs(
    loader, model, folder="saved_images/", device="cuda"
):
    model.eval()
    for idx, (x, y) in enumerate(loader):
        x = x.to(device=device)
        with torch.no_grad():
            preds = torch.sigmoid(model(x))
            preds = (preds > 0.5).float()
        torchvision.utils.save_image(
            preds, f"{folder}/pred_{idx}.png"
        )
        torchvision.utils.save_image(y.unsqueeze(1), f"{folder}{idx}.png")

    model.train()

# %%
import torch.optim as optim
from tqdm import tqdm


LEARNING_RATE = 1e-4
NUM_EPOCHS= 10
LOAD_CHECKPOINT= True

model = UNET(in_channels=3, out_channels=1).to('cuda')
loss_fn = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

if LOAD_CHECKPOINT:
        print("loading checkpoints")
        load_checkpoint(torch.load("my_checkpoint.pth.tar"), model)

check_accuracy(val_loader, model, device='cuda')
scaler = torch.cuda.amp.GradScaler()
for epoch in range(NUM_EPOCHS):
        train_fn(train_loader, model, optimizer, loss_fn, scaler)

        checkpoint = {
            "state_dict": model.state_dict(),
            "optimizer":optimizer.state_dict(),
        }
        save_checkpoint(checkpoint)

        # check accuracy
        check_accuracy(val_loader, model, device='cuda')

        # print some examples to a folder
        save_predictions_as_imgs(
            val_loader, model, folder="saved_images", device='cuda'
        )
# Out:
# loading checkpoints
# => Loading checkpoint
# Got 39076846/40894464 with acc 95.56
# Dice score: 0.0
# 100%|██████████| 312/312 [02:35<00:00,  2.01it/s, loss=0.0872]
# => Saving checkpoint
# Got 39323674/40894464 with acc 96.16
# Dice score: 0.35532236099243164
# 100%|██████████| 312/312 [02:34<00:00,  2.02it/s, loss=0.0834]
# => Saving checkpoint
# Got 39326790/40894464 with acc 96.17
# Dice score: 0.5299746990203857
# 100%|██████████| 312/312 [02:35<00:00,  2.00it/s, loss=0.105]
# => Saving checkpoint
# Got 39546220/40894464 with acc 96.70
# Dice score: 0.5548849701881409
# 100%|██████████| 312/312 [02:33<00:00,  2.03it/s, loss=0.0592]
# => Saving checkpoint
# Got 39508523/40894464 with acc 96.61
# Dice score: 0.4386116862297058
# 100%|██████████| 312/312 [02:36<00:00,  1.99it/s, loss=0.148]
# => Saving checkpoint
# Got 39648811/40894464 with acc 96.95
# Dice score: 0.6037576794624329
# 100%|██████████| 312/312 [02:35<00:00,  2.00it/s, loss=0.0614]
# => Saving checkpoint
# Got 39685582/40894464 with acc 97.04
# Dice score: 0.6099926233291626
# 100%|██████████| 312/312 [02:35<00:00,  2.01it/s, loss=0.216]
# => Saving checkpoint
# Got 39704582/40894464 with acc 97.09
# Dice score: 0.6381580233573914
# 100%|██████████| 312/312 [02:36<00:00,  2.00it/s, loss=0.114]
# => Saving checkpoint
# Got 39713006/40894464 with acc 97.11
# Dice score: 0.5949724316596985
# 100%|██████████| 312/312 [02:37<00:00,  1.99it/s, loss=0.0844]
# => Saving checkpoint
# Got 39756889/40894464 with acc 97.22
# Dice score: 0.627429723739624
# 100%|██████████| 312/312 [02:38<00:00,  1.97it/s, loss=0.0945]
# => Saving checkpoint
# Got 39724303/40894464 with acc 97.14
# Dice score: 0.632401168346405

# %%
os.mkdir('saved_images')

# %%
from PIL import Image
image = Image.open('vit1 (1).jpg')

# %%
from torchvision.transforms import v2

trans = v2.PILToTensor()
img_tensor = trans(image)

# %%
img_tensor.shape
# Out:
# torch.Size([3, 821, 1753])

# %%
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

# %matplotlib inline

transt = transforms.ToTensor()
transp = transforms.ToPILImage()
img_t = transt(Image.open('vit1 (1).jpg'))

#torch.Tensor.unfold(dimension, size, step)
#slices the images into 8*8 size patches
patches = img_t.data.unfold(0, 3, 3).unfold(1, 8, 8).unfold(2, 8, 8)


print(patches[0][0][0].shape)

def visualize(patches):
    """Imshow for Tensor."""
    fig = plt.figure(figsize=(4, 4))
    for i in range(4):
        for j in range(4):
            inp = transt(patches[0][i][j])
            inp = np.array(inp)

            ax = fig.add_subplot(4, 4, ((i*4)+j)+1, xticks=[], yticks=[])
            plt.imshow(inp)

visualize(patches)
# Out:
# torch.Size([3, 255, 255])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-05e274dcd65b> in <cell line: 29>()
#      27             plt.imshow(inp)
#      28
# ---> 29 visualize(patches)
#
# <ipython-input-128-05e274dcd65b> in visualize(patches)
#      21     for i in range(4):
#      22         for j in range(4):
# ---> 23             inp = transp(patches[0][i][j])
#      24             inp = np.array(inp)
#      25
#
# IndexError: index 3 is out of bounds for dimension 0 with size 3

# %%
bruh = img_t.data.unfold(0, 3, 3)

# %%
bruh.unfold(1, 8, 8).shape
# Out:
# torch.Size([1, 102, 1753, 3, 8])

# %%
img_t.shape
# Out:
# torch.Size([3, 821, 1753])

# %%
import torch

# Your original tensor
original_tensor = torch.randn(3, 821, 1753)

# Specify block size
block_size = (256, 256)

# Use unfold to create a view of the tensor as blocks
unfolded_tensor = original_tensor.unfold(1, block_size[0], block_size[0]).unfold(2, block_size[1], block_size[1])

# Get the size of the unfolded tensor
unfolded_size = unfolded_tensor.size()

# Reshape the unfolded tensor to get the final result
result_tensor = unfolded_tensor.reshape(unfolded_size[0], unfolded_size[1], unfolded_size[2], block_size[0], block_size[1])

# Check the size of the result tensor
print(result_tensor.size())
# Out:
# torch.Size([3, 3, 6, 256, 256])

# %%
import torch

# Assuming result_tensor is your unfolded tensor
result_tensor = torch.randn(3, 3, 6, 256, 256)

# Get the dimensions of the unfolded tensor
num_channels, num_blocks_dim1, num_blocks_dim2, block_size_dim1, block_size_dim2 = result_tensor.size()

# Iterate over each dimension to extract each block
for channel_idx in range(num_channels):
    for block_idx_dim1 in range(num_blocks_dim1):
        for block_idx_dim2 in range(num_blocks_dim2):
            # Extract a single block
            block = result_tensor[channel_idx, block_idx_dim1, block_idx_dim2, :, :]

            # Now 'block' is a tensor of size (256, 256), representing one block of the original tensor
            # You can perform operations on 'block' or store it as needed
            print(f"Channel {channel_idx}, Block {block_idx_dim1}, {block_idx_dim2}:\n", block.shape)
# Out:
# Channel 0, Block 0, 0:
#  torch.Size([256, 256])
# Channel 0, Block 0, 1:
#  torch.Size([256, 256])
# Channel 0, Block 0, 2:
#  torch.Size([256, 256])
# Channel 0, Block 0, 3:
#  torch.Size([256, 256])
# Channel 0, Block 0, 4:
#  torch.Size([256, 256])
# Channel 0, Block 0, 5:
#  torch.Size([256, 256])
# Channel 0, Block 1, 0:
#  torch.Size([256, 256])
# Channel 0, Block 1, 1:
#  torch.Size([256, 256])
# Channel 0, Block 1, 2:
#  torch.Size([256, 256])
# Channel 0, Block 1, 3:
#  torch.Size([256, 256])
# Channel 0, Block 1, 4:
#  torch.Size([256, 256])
# Channel 0, Block 1, 5:
#  torch.Size([256, 256])
# Channel 0, Block 2, 0:
#  torch.Size([256, 256])
# Channel 0, Block 2, 1:
#  torch.Size([256, 256])
# Channel 0, Block 2, 2:
#  torch.Size([256, 256])
# Channel 0, Block 2, 3:
#  torch.Size([256, 256])
# Channel 0, Block 2, 4:
#  torch.Size([256, 256])
# Channel 0, Block 2, 5:
#  torch.Size([256, 256])
# Channel 1, Block 0, 0:
#  torch.Size([256, 256])
# Channel 1, Block 0, 1:
#  torch.Size([256, 256])
# Channel 1, Block 0, 2:
#  torch.Size([256, 256])
# Channel 1, Block 0, 3:
#  torch.Size([256, 256])
# Channel 1, Block 0, 4:
#  torch.Size([256, 256])
# Channel 1, Block 0, 5:
#  torch.Size([256, 256])
# Channel 1, Block 1, 0:
#  torch.Size([256, 256])
# Channel 1, Block 1, 1:
#  torch.Size([256, 256])
# Channel 1, Block 1, 2:
#  torch.Size([256, 256])
# Channel 1, Block 1, 3:
#  torch.Size([256, 256])
# Channel 1, Block 1, 4:
#  torch.Size([256, 256])
# Channel 1, Block 1, 5:
#  torch.Size([256, 256])
# Channel 1, Block 2, 0:
#  torch.Size([256, 256])
# Channel 1, Block 2, 1:
#  torch.Size([256, 256])
# Channel 1, Block 2, 2:
#  torch.Size([256, 256])
# Channel 1, Block 2, 3:
#  torch.Size([256, 256])
# Channel 1, Block 2, 4:
#  torch.Size([256, 256])
# Channel 1, Block 2, 5:
#  torch.Size([256, 256])
# Channel 2, Block 0, 0:
#  torch.Size([256, 256])
# Channel 2, Block 0, 1:
#  torch.Size([256, 256])
# Channel 2, Block 0, 2:
#  torch.Size([256, 256])
# Channel 2, Block 0, 3:
#  torch.Size([256, 256])
# Channel 2, Block 0, 4:
#  torch.Size([256, 256])
# Channel 2, Block 0, 5:
#  torch.Size([256, 256])
# Channel 2, Block 1, 0:
#  torch.Size([256, 256])
# Channel 2, Block 1, 1:
#  torch.Size([256, 256])
# Channel 2, Block 1, 2:
#  torch.Size([256, 256])
# Channel 2, Block 1, 3:
#  torch.Size([256, 256])
# Channel 2, Block 1, 4:
#  torch.Size([256, 256])
# Channel 2, Block 1, 5:
#  torch.Size([256, 256])
# Channel 2, Block 2, 0:
#  torch.Size([256, 256])
# Channel 2, Block 2, 1:
#  torch.Size([256, 256])
# Channel 2, Block 2, 2:
#  torch.Size([256, 256])
# Channel 2, Block 2, 3:
#  torch.Size([256, 256])
# Channel 2, Block 2, 4:
#  torch.Size([256, 256])
# Channel 2, Block 2, 5:
#  torch.Size([256, 256])

# %%
num_blocks = tuple((original_tensor.size(i) - block_size[i] + 1) // block_size[i] for i in range(1, 3))
